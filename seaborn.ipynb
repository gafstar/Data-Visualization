# %%
import pandas as pd

# %%
 s = pd.Series([3, -5, 7, 4], index=['a', 'b', 'c', 'd'])

# %%
pwd
# Out:
# '/Users/ghezaefisseha'

# %%
pwd
# Out:
# '/Users/ghezaefisseha'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
reviews=pd.read_csv('ign.csv')

# %%
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
reviewed =reviews.iloc[:, 1:]

# %%
reviewed.head()
# Out:
#   score_phrase                                              title  \
# 0      Amazing                            LittleBigPlanet PS Vita
# 1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2        Great                               Splice: Tree of Life
# 3        Great                                             NHL 13
# 4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# 1  Platformer              Y          2012              9           12
# 2      Puzzle              N          2012              9           12
# 3      Sports              N          2012              9           11
# 4      Sports              N          2012              9           11

# %%
reviews.index.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-e8a62906de65> in <module>()
# ----> 1 reviews.index.head()
#
# AttributeError: 'RangeIndex' object has no attribute 'head'

# %%
reviews.index
# Out:
# RangeIndex(start=0, stop=18625, step=1)

# %%
reviewed.loc[8:23, :]
# Out:
#    score_phrase                            title  \
# 8         Awful              Double Dragon: Neon
# 9          Good        Total War Battles: Shogun
# 10         Good          Tekken Tag Tournament 2
# 11         Good          Tekken Tag Tournament 2
# 12         Good                       Wild Blood
# 13      Amazing                Mark of the Ninja
# 14      Amazing                Mark of the Ninja
# 15         Okay  Home: A Unique Horror Adventure
# 16         Okay  Home: A Unique Horror Adventure
# 17        Great              Avengers Initiative
# 18     Mediocre             Way of the Samurai 4
# 19         Good      JoJo's Bizarre Adventure HD
# 20         Good      JoJo's Bizarre Adventure HD
# 21         Good         Mass Effect 3: Leviathan
# 22         Good         Mass Effect 3: Leviathan
# 23         Good         Mass Effect 3: Leviathan
#
#                                                   url       platform  score  \
# 8                /games/double-dragon-neon/ps3-131321  PlayStation 3    3.0
# 9           /games/total-war-battles-shogun/pc-142564             PC    7.0
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14          /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
# 15  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
# 16    /games/home-a-unique-horror-adventure/pc-137135             PC    6.5
# 17           /games/avengers-initiative/iphone-141579         iPhone    8.0
# 18              /games/way-of-the-samurai-4/ps3-23516  PlayStation 3    5.5
# 19     /games/jojos-bizarre-adventure/xbox-360-137717       Xbox 360    7.0
# 20          /games/jojos-bizarre-adventure/ps3-137896  PlayStation 3    7.0
# 21     /games/mass-effect-3-leviathan/xbox-360-138918       Xbox 360    7.5
# 22          /games/mass-effect-3-leviathan/ps3-138915  PlayStation 3    7.5
# 23           /games/mass-effect-3-leviathan/pc-138919             PC    7.5
#
#                 genre editors_choice  release_year  release_month  release_day
# 8            Fighting              N          2012              9           11
# 9            Strategy              N          2012              9           11
# 10           Fighting              N          2012              9           11
# 11           Fighting              N          2012              9           11
# 12                NaN              N          2012              9           10
# 13  Action, Adventure              Y          2012              9            7
# 14  Action, Adventure              Y          2012              9            7
# 15          Adventure              N          2012              9            6
# 16          Adventure              N          2012              9            6
# 17             Action              N          2012              9            5
# 18  Action, Adventure              N          2012              9            3
# 19           Fighting              N          2012              9            3
# 20           Fighting              N          2012              9            3
# 21                RPG              N          2012              8           31
# 22                RPG              N          2012              8           31
# 23                RPG              N          2012              8           31

# %% [raw]
# reviewed['score']

# %%
reviews["score"]
# Out:
# 0         9.0
# 1         9.0
# 2         8.5
# 3         8.5
# 4         8.5
# 5         7.0
# 6         3.0
# 7         9.0
# 8         3.0
# 9         7.0
# 10        7.5
# 11        7.5
# 12        7.0
# 13        9.0
# 14        9.0
# 15        6.5
# 16        6.5
# 17        8.0
# 18        5.5
# 19        7.0
# 20        7.0
# 21        7.5
# 22        7.5
# 23        7.5
# 24        9.0
# 25        7.0
# 26        9.0
# 27        7.5
# 28        8.0
# 29        6.5
#          ...
# 18595     4.4
# 18596     6.5
# 18597     4.9
# 18598     6.8
# 18599     7.0
# 18600     7.4
# 18601     7.4
# 18602     7.4
# 18603     7.8
# 18604     8.6
# 18605     6.0
# 18606     6.4
# 18607     7.0
# 18608     5.4
# 18609     8.0
# 18610     6.0
# 18611     5.8
# 18612     7.8
# 18613     8.0
# 18614     9.2
# 18615     9.2
# 18616     7.5
# 18617     8.4
# 18618     9.1
# 18619     7.9
# 18620     7.6
# 18621     9.0
# 18622     5.8
# 18623    10.0
# 18624    10.0
# Name: score, Length: 18625, dtype: float64

# %%
s1 = pd.Series([2,3])

# %%
s1
# Out:
# 0    2
# 1    3
# dtype: int64

# %%
type (reviews['title'])
# Out:
# pandas.core.series.Series

# %%
reviews.corr()
# Out:
#                Unnamed: 0     score  release_year  release_month  release_day
# Unnamed: 0       1.000000  0.035579      0.893394      -0.096676     0.010068
# score            0.035579  1.000000      0.062716       0.007632     0.020079
# release_year     0.893394  0.062716      1.000000      -0.115515     0.016867
# release_month   -0.096676  0.007632     -0.115515       1.000000    -0.067964
# release_day      0.010068  0.020079      0.016867      -0.067964     1.000000

# %%
# %matplotlib inline

# %%
reviews[reviews['platform']=='Xbox One']['score'].plot(kind='hist')

# %%
filtered_reviews['score'].hist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-6a5a5b57929e> in <module>()
# ----> 1 filtered_reviews['score'].hist()
#
# NameError: name 'filtered_reviews' is not defined

# %%
import seaborn as sns
df = sns.load_dataset('iris')

# %%
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='reg')
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# /Applications/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.set(style="white", color_codes=True)
sns.jointplot(x=df["sepal_length"], y=df["sepal_width"], kind='kde', color="skyblue")

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df = sns.load_dataset('iris')

# %%
sns.pairplot(df, hue ='species')

# %%
sns.pairplot(df, kind='scatter', hue='species', plot_kws=dict(s=80, edgecolor ='white', linewidth=2.5))

# %%
import seaborn as sns; sns.set(style='ticks', color_codes=True)
iris = sns.load_dataset('iris')

# %%
import seaborn as sns
sns.set(style="darkgrid")

# %%
fm=sns.load_dataset('fmri')

# %%
fm.shape
# Out:
# (1064, 5)

# %%
ax = sns.lineplot(x="timepoint", y="signal", hue="event",
                   units="subject", estimator=None, lw=1,
                   data=fmri.query("region == 'frontal'"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-ecd81e21ec2f> in <module>()
# ----> 1 sns.lineplot(x='timepoint', y='signal', hue='region',style= 'event', data='fmri')
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
sns.lineplot(x="timepoint", y="signal",
             hue="region", style="event",
             data=fmri)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-d58bf690b292> in <module>()
# ----> 1 sns.lineplot(x="timepoint", y="signal",
#       2              hue="region", style="event",
#       3              data=fmri)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-8f312baee4ba> in <module>()
# ----> 1 ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
fmri = sns.load_dataset("fmri")
ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-a2e8bc0d9af0> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 fmri = sns.load_dataset("fmri")
# ----> 4 ax = sns.lineplot(x="timepoint", y="signal", data=fmri)
#
# AttributeError: module 'seaborn' has no attribute 'lineplot'

# %%
g=sns.pairplot(iris)

# %%
import seaborn as sns; sns.set(style='ticks', color_codes=True)
iris = sns.load_dataset('iris')
g=sns.pairplot(iris)

# %%
g= sns.pairplot(iris, hue= 'species')

# %%
g = sns.pairplot(iris, hue="species", palette="husl")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="darkgrid")

# %%
tips = sns.load_dataset("tips")
sns.relplot(x="total_bill", y="tip", data=tips);

# %%
sns.relplot(x="total_bill", y="tip", hue='smoker', style='smoker',data=tips);

# %%
sns.relplot(x='total_bill', y='tip', hue='size', data=tips)

# %%
sns.relplot(x="total_bill", y="tip", hue="size", sizes=(15, 200), data=tips);

# %%
df=pd.DataFrame(dict(time=np.arange(500), value=np.random.randn(500).cumsum()))
g=sns.relplot(x='time', y='value', kind='line', data=df)
g.fig.autofmt_xdate()

# %%
fmri=sns.load_dataset('fmri')

# %%
sns.relplot(x='timepoint', y='signal', kind='line',estimator=None,data=fmri);

# %%
sns.relplot(x='timepoint', y='signal',hue='event', kind='line',data=fmri);
# Out:
# /Applications/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1064 entries, 0 to 1063
# Data columns (total 5 columns):
# subject      1064 non-null object
# timepoint    1064 non-null int64
# event        1064 non-null object
# region       1064 non-null object
# signal       1064 non-null float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 41.6+ KB

# %%
dots=sns.load_dataset('dots')

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
palette = sns.cubehelix_palette(light=.8, n_colors=6)
sns.relplot(x='time', y='firing_rate',ci=None, hue ='coherence', palette= palette,style='choice',  kind = 'line', data=dots)

# %%
df = pd.DataFrame(dict(time=pd.date_range("2017-1-1", periods=500),
                       value=np.random.randn(500).cumsum()))

# %%
df.head()
# Out:
#         time     value
# 0 2017-01-01 -0.886328
# 1 2017-01-02  0.978664
# 2 2017-01-03 -0.649558
# 3 2017-01-04 -0.483114
# 4 2017-01-05 -1.938261

# %%
g=sns.relplot(x='time', y='value', kind='line', data=df)
g.fig.autofmt_xdate()

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x='total_bill', y='tip', hue='smoker', col='time',data=tips)

# %%
sns.relplot(x='timepoint', y='signal', hue='subject', col='region', row='event', height=3, kind='line',estimator=None, data=fmri)

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt
tips = sns.load_dataset("tips")
ax = sns.scatterplot(x="total_bill", y="tip", hue='day',style='time', data=tips)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax=sns.scatterplot(x='total_bill', y='tip', hue='size', size='size', data=tips)

# %%
cmap=sns.cubehelix_palette(dark=.3, light=.8, as_cmap=True)

# %%
ax=sns.scatterplot(x='total_bill', y='tip', hue='day', size='smoker',  palette='Set2', data=tips)

# %%
ax=sns.scatterplot(x='total_bill', y='tip', hue='day', size='smoker',  palette='Set2', data=tips)

# %%
markers={'Lunch':'s','Dinner':'X'}

# %%
ax=sns.scatterplot(x='total_bill', y='tip', style='time', markers=markers, data=tips)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-56-c5a05363d1d4> in <module>()
# ----> 1 ax=sns.scatterplot(x='total_bill', y='tip', style='time', markers=markers, data=tips)
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1333         x_bins=x_bins, y_bins=y_bins,
#    1334         estimator=estimator, ci=ci, n_boot=n_boot,
# -> 1335         alpha=alpha, x_jitter=x_jitter, y_jitter=y_jitter, legend=legend,
#    1336     )
#    1337
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in __init__(self, x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend)
#     859         self.parse_hue(plot_data["hue"], palette, hue_order, hue_norm)
#     860         self.parse_size(plot_data["size"], sizes, size_order, size_norm)
# --> 861         self.parse_style(plot_data["style"], markers, None, style_order)
#     862         self.units = units
#     863
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in parse_style(self, data, markers, dashes, order)
#     488
#     489             markers = self.style_to_attributes(
# --> 490                 levels, markers, self.default_markers, "markers"
#     491             )
#     492
#
# /Applications/anaconda3/lib/python3.6/site-packages/seaborn/relational.py in style_to_attributes(self, levels, style, defaults, name)
#     303             if any(missing_levels):
#     304                 err = "These `style` levels are missing {}: {}"
# --> 305                 raise ValueError(err.format(name, missing_levels))
#     306
#     307         return attrdict
#
# ValueError: These `style` levels are missing markers: {'Lunch'}

# %%
ax = sns.scatterplot(x="total_bill", y="tip", style="time",
                      markers=markers,
                      data=tips)

# %%
iris=sns.load_dataset('iris')

# %%
ax=sns.scatterplot(x=iris['sepal_length'], y=iris['sepal_width'], hue=iris['species'], style=iris['species'])

# %%
sns.relplot(x='total_bill', y='tip', row='time', hue='smoker',style='smoker', size='size', data=tips)
